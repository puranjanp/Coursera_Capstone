# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
csv_catalog = 'catalog_data.csv'
df_cat = pd.read_csv(csv_catalog)

# %%
df_cat.shape
# Out:
# (1604389, 32)

# %%
xl_auc = 'auction_data_combined.xlsx'
df_auc = pd.read_excel(xl_auc)

# %%
df_auc.shape
# Out:
# (312, 73)

# %%
df_cat.head()
# Out:
#   BROK_CD AUCTC_CD  SALE_NO  LOT_NO GRD_CD  TEA_TYPE       G_CODE INV_NO  \
# 0     PAR        G        5    3118     PD         2      BOROKAI   D702
# 1     PAR        G        5    3119    PD1         2  BUNDOOKMARA  DC596
# 2     PAR        G        5    3120    PD1         2  BUNDOOKMARA  DC600
# 3     PAR        G        5    3121    PD1         2  BUNDOOKMARA  DC611
# 4     PAR        G        5    3083     D1         2      UMABARI  DC440
#
#    INV_DT  N_O_BAGS  ...  PRAM_CODE4_VAL  PRAM_CODE6_VAL  PRAM_CODE8_VAL  \
# 0     NaN        10  ...             3.0             2.0            25.0
# 1     NaN        30  ...             2.0             3.0            25.0
# 2     NaN        20  ...             2.0             3.0            25.0
# 3     NaN        20  ...             2.0             3.0            25.0
# 4     NaN        17  ...             2.0             3.0            25.0
#
#    PRAM_CODE9_VAL PRAM_CODE10_VAL  PRAM_CODE13_VAL ARRIVAL_DT  MATRL_CODE  \
# ...

# %%
df_auc.head()
# Out:
#   Center  cur_Year Week_ending     cur_yr_sale_date  cur_yr_sale_no  \
# 0    GHY      2016  2016-01-09  2016-01-05 00:00:00               1
# 1    GHY      2016  2016-01-16  2016-01-12 00:00:00               2
# 2    GHY      2016  2016-01-23  2016-01-19 00:00:00               3
# 3    GHY      2016  2016-01-30  2016-01-26 00:00:00               4
# 4    GHY      2016  2016-02-06  2016-02-02 00:00:00               5
#
#    cur_yr_Offer_CTC_Leaf_Qty_in_Kgs  cur_yr_Offer_CTC_Dust_Qty_in_Kgs  \
# 0                         4675589.9                         1792203.8
# 1                         1713211.9                          943801.1
# 2                         4383979.5                         1495639.6
# 3                         2865200.3                          891447.1
# 4                         2735166.1                          721424.2
#
#    cur_yr_Offer_Ortho_Leaf_Qty_in_Kgs  cur_yr_Offer_Ortho_Dust_Qty_in_Kgs  \
# ...

# %%
df_cat.describe(include='all')
# Out:
#         BROK_CD AUCTC_CD       SALE_NO        LOT_NO   GRD_CD      TEA_TYPE  \
# count   1604389  1604389  1.604389e+06  1.604389e+06  1604389  1.604389e+06
# unique       15        2           NaN           NaN      875           NaN
# top          JT        K           NaN           NaN       BP           NaN
# freq     663475   868750           NaN           NaN   302601           NaN
# mean        NaN      NaN  2.977213e+01  1.933829e+03      NaN  1.602704e+00
# std         NaN      NaN  1.521392e+01  2.052026e+03      NaN  9.043159e-01
# min         NaN      NaN  1.000000e+00  1.000000e+00      NaN  1.000000e+00
# 25%         NaN      NaN  1.900000e+01  2.390000e+02      NaN  1.000000e+00
# 50%         NaN      NaN  3.200000e+01  8.150000e+02      NaN  1.000000e+00
# 75%         NaN      NaN  4.300000e+01  3.167000e+03      NaN  2.000000e+00
# max         NaN      NaN  5.200000e+01  3.198100e+04      NaN  5.000000e+00
#
# ...

# %%
df_cat.dtypes
# Out:
# BROK_CD             object
# AUCTC_CD            object
# SALE_NO              int64
# LOT_NO               int64
# GRD_CD              object
# TEA_TYPE             int64
# G_CODE              object
# INV_NO              object
# INV_DT             float64
# N_O_BAGS             int64
# PUR_N_BAGS         float64
# NET_WT             float64
# GROSS_WT           float64
# PUR_P_KG           float64
# COMP_CD1            object
# COMP_1_QTY         float64
# COMP_CD2            object
# COMP_2_QTY         float64
# COMP_CD3            object
# COMP_3_QTY         float64
# COMP_CD4           float64
# COMP_4_QTY         float64
# PRAM_CODE4_VAL     float64
# PRAM_CODE6_VAL     float64
# PRAM_CODE8_VAL     float64
# PRAM_CODE9_VAL     float64
# PRAM_CODE10_VAL    float64
# PRAM_CODE13_VAL    float64
# ARRIVAL_DT          object
# MATRL_CODE          object
# SALE_DATE           object
# CTC_ORTH            object
# year                 int64
# dtype: object

# %%
df_cat['year'] = pd.DatetimeIndex(df_cat['SALE_DATE']).year

# %%
df_cat['month'] = pd.DatetimeIndex(df_cat['SALE_DATE']).month

# %%
df_cat.head()
# Out:
#   BROK_CD AUCTC_CD  SALE_NO  LOT_NO GRD_CD  TEA_TYPE       G_CODE INV_NO  \
# 0     PAR        G        5    3118     PD         2      BOROKAI   D702
# 1     PAR        G        5    3119    PD1         2  BUNDOOKMARA  DC596
# 2     PAR        G        5    3120    PD1         2  BUNDOOKMARA  DC600
# 3     PAR        G        5    3121    PD1         2  BUNDOOKMARA  DC611
# 4     PAR        G        5    3083     D1         2      UMABARI  DC440
#
#    INV_DT  N_O_BAGS  ...  PRAM_CODE8_VAL  PRAM_CODE9_VAL  PRAM_CODE10_VAL  \
# 0     NaN        10  ...            25.0            24.0             12.0
# 1     NaN        30  ...            25.0            24.0             12.0
# 2     NaN        20  ...            25.0            24.0             12.0
# 3     NaN        20  ...            25.0            24.0             12.0
# 4     NaN        17  ...            25.0            24.0             15.0
#
#    PRAM_CODE13_VAL ARRIVAL_DT  MATRL_CODE  SALE_DATE  CTC_ORTH  year  month
# ...

# %%
df_cat.to_csv("catlog_2016_to_2018.csv")

# %%
df_cat.describe(include='all')
# Out:
#         BROK_CD AUCTC_CD       SALE_NO        LOT_NO   GRD_CD      TEA_TYPE  \
# count   1604389  1604389  1.604389e+06  1.604389e+06  1604389  1.604389e+06
# unique       15        2           NaN           NaN      875           NaN
# top          JT        K           NaN           NaN       BP           NaN
# freq     663475   868750           NaN           NaN   302601           NaN
# mean        NaN      NaN  2.977213e+01  1.933829e+03      NaN  1.602704e+00
# std         NaN      NaN  1.521392e+01  2.052026e+03      NaN  9.043159e-01
# min         NaN      NaN  1.000000e+00  1.000000e+00      NaN  1.000000e+00
# 25%         NaN      NaN  1.900000e+01  2.390000e+02      NaN  1.000000e+00
# 50%         NaN      NaN  3.200000e+01  8.150000e+02      NaN  1.000000e+00
# 75%         NaN      NaN  4.300000e+01  3.167000e+03      NaN  2.000000e+00
# max         NaN      NaN  5.200000e+01  3.198100e+04      NaN  5.000000e+00
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
colors = (0,0,0)
area = np.pi*5
x=df_cat["GRD_CD"]
y=df_cat["PUR_P_KG"]

plt.scatter(x, y, s=area, c=colors, edgecolors='none', alpha=0.5)

plt.title("Scatterplot of Grade vs. Price")
plt.xlabel("Grade")
plt.ylabel("Price")
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import seaborn as sns

# %%
df_cat.describe()
# Out:
#             SALE_NO        LOT_NO      TEA_TYPE  INV_DT      N_O_BAGS  \
# count  1.604389e+06  1.604389e+06  1.604389e+06     0.0  1.604389e+06
# mean   2.977213e+01  1.933829e+03  1.602704e+00     NaN  2.519360e+01
# std    1.521392e+01  2.052026e+03  9.043159e-01     NaN  1.184941e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00     NaN -4.000000e+01
# 25%    1.900000e+01  2.390000e+02  1.000000e+00     NaN  2.000000e+01
# 50%    3.200000e+01  8.150000e+02  1.000000e+00     NaN  2.000000e+01
# 75%    4.300000e+01  3.167000e+03  2.000000e+00     NaN  3.000000e+01
# max    5.200000e+01  3.198100e+04  5.000000e+00     NaN  9.990000e+02
#
#           PUR_N_BAGS        NET_WT      GROSS_WT      PUR_P_KG    COMP_1_QTY  \
# count  157913.000000  1.604389e+06  1.604389e+06  1.089740e+06  1.001800e+06
# mean       19.681261  3.186635e+01  3.333229e+01  1.584345e+02  1.805450e+01
# std         8.053452  6.920865e+00  5.067057e+01  8.715341e+01  7.980823e+00
# ...

# %%
df_cat_2016 = df_cat[df_cat["year"] == 2016]

# %%
df_cat_2017 = df_cat[df_cat['year'] == "2017"]

# %%
df_cat_2018 = df_cat[df_cat['year'] == "2018"]

# %%
df_cat_2016.shape
# Out:
# (464527, 34)

# %%
df_cat_2017 = df_cat[df_cat['year'] == 2017]
df_cat_2018 = df_cat[df_cat['year'] == 2018]

# %%
df_cat_2018 = df_cat_2018[["GRD_CD","N_O_BAGS","NET_WT","PUR_P_KG","PUR_N_BAGS","year","month"]]

# %%
df_cat_2017 = df_cat_2017[["GRD_CD","N_O_BAGS","NET_WT","PUR_P_KG","PUR_N_BAGS","year","month"]]

df_cat_2016 = df_cat_2016[["GRD_CD","N_O_BAGS","NET_WT","PUR_P_KG","PUR_N_BAGS","year","month"]]

# %%
df_cat_2018.N_O_BAGS = df_cat_2018.N_O_BAGS.astype(int)
df_cat_2018.NET_WT = df_cat_2018.NET_WT.astype(float)

# %%
df_cat_2018['tot_kgs'] = df_cat_2018['N_O_BAGS'] * df_cat_2018['NET_WT']

# %%
df_cat_2017['tot_kgs'] = df_cat_2017['N_O_BAGS'] * df_cat_2017['NET_WT']
df_cat_2016['tot_kgs'] = df_cat_2016['N_O_BAGS'] * df_cat_2016['NET_WT']

# %%
df_cat_2018.drop(['N_O_BAGS', 'NET_WT'], axis=1, inplace=True)
df_cat_2017.drop(['N_O_BAGS', 'NET_WT'], axis=1, inplace=True)
df_cat_2016.drop(['N_O_BAGS', 'NET_WT'], axis=1, inplace=True)

# %%
sns.pairplot(df_cat_2018)

# %%
df_cat_2018.describe()
# Out:
#             PUR_P_KG    PUR_N_BAGS      year          month        tot_kgs
# count  393257.000000  61556.000000  587845.0  587845.000000  587845.000000
# mean      162.919984     19.185132    2018.0       7.263081     763.011359
# std        91.998120      6.916058       0.0       3.473807     358.158830
# min         1.000000      1.000000    2018.0       1.000000       3.000000
# 25%       121.000000     15.000000    2018.0       5.000000     520.000000
# 50%       146.000000     20.000000    2018.0       8.000000     740.000000
# 75%       186.000000     20.000000    2018.0      10.000000    1000.000000
# max      7601.000000     85.000000    2018.0      12.000000    6000.000000

# %%
df_cat_2018.to_csv("cat_2018.csv")
df_cat_2017.to_csv("cat_2017.csv")
df_cat_2016.to_csv("cat_2016.csv")

# %%
csv_cat1 = 'cat_2018.csv'
df_cat_2018 = pd.read_csv(csv_cat1)

# %%
df_cat_2018.describe(include='all')
# Out:
#           Unnamed: 0  GRD_CD       PUR_P_KG     PUR_N_BAGS      year  \
# count   5.878450e+05  587845  587845.000000  587845.000000  587845.0
# unique           NaN     505            NaN            NaN       NaN
# top              NaN      BP            NaN            NaN       NaN
# freq             NaN  109350            NaN            NaN       NaN
# mean    1.035220e+06     NaN     108.990336       2.008965    2018.0
# std     4.392713e+05     NaN     107.423635       6.286096       0.0
# min     3.795610e+05     NaN       0.000000       0.000000    2018.0
# 25%     6.054070e+05     NaN       0.000000       0.000000    2018.0
# 50%     1.286044e+06     NaN     122.000000       0.000000    2018.0
# 75%     1.457427e+06     NaN     163.000000       0.000000    2018.0
# max     1.604388e+06     NaN    7601.000000      85.000000    2018.0
#
#                 month        tot_kgs
# count   587845.000000  587845.000000
# unique            NaN            NaN
# ...

# %%
csv_cat2 = 'cat_2017.csv'
df_cat_2017 = pd.read_csv(csv_cat2)
csv_cat3 = 'cat_2016.csv'
df_cat_2016 = pd.read_csv(csv_cat3)

# %%
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

# %%
X
# Out:
# array([['BOPSM', 71.0, 0.0, 2018, 3, 230.0],
#        ['BOP', 0.0, 0.0, 2018, 3, 248.0],
#        ['BOPSM', 63.0, 0.0, 2018, 3, 196.0],
#        ...,
#        ['PD', 220.0, 0.0, 2018, 11, 660.0],
#        ['BP', 0.0, 0.0, 2018, 11, 560.0],
#        ['STGBOP1', 242.0, 0.0, 2018, 12, 198.0]], dtype=object)

# %%
df_cat_2018.fillna(0, inplace=True)

# %%
df_cat_2017.fillna(0, inplace=True)
df_cat_2016.fillna(0, inplace=True)

# %%
df_grade_2018 = df_cat_2018[["GRD_CD","year"]]
df_grade_2017 = df_cat_2017[["GRD_CD","year"]]
df_grade_2016 = df_cat_2016[["GRD_CD","year"]]

# %%
df_grade_2018.head()
# Out:
#         year  grade_id
# GRD_CD
# BOPSM   2018         1
# BOP     2018         2
# BP      2018         3
# BPS     2018         4
# BP1     2018         5

# %%
df_grade_2018.drop_duplicates(subset=['GRD_CD','year'], keep='first', inplace=True)
df_grade_2017.drop_duplicates(subset=['GRD_CD','year'], keep='first', inplace=True)
df_grade_2016.drop_duplicates(subset=['GRD_CD','year'], keep='first', inplace=True)
# Out:
# C:\Users\puranjan.pathak\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\puranjan.pathak\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\puranjan.pathak\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
csv_grd1 = 'grade2018.csv'
df_grade_2018 = pd.read_csv(csv_grd1, index_col="GRD_CD")
csv_grd2 = 'grade2017.csv'
df_grade_2017 = pd.read_csv(csv_grd2, index_col="GRD_CD")
csv_grd3 = 'grade2016.csv'
df_grade_2016 = pd.read_csv(csv_grd3, index_col="GRD_CD")

# %%
df_cat_2018.set_index(["GRD_CD"], inplace = True)

# %%
df_cat_2017.set_index(["GRD_CD"], inplace = True)
df_cat_2016.set_index(["GRD_CD"], inplace = True)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-62084d854a4d> in <module>
# ----> 1 df_cat_2018 = pd.merge(left=df_cat_2018,right=df_grade_2018, left_on='GRD_CD', right_on='GRD_CD', inplace=True)
#
# TypeError: merge() got an unexpected keyword argument 'inplace'

# %%
df_cat_2018.head()
# Out:
#           PUR_P_KG  PUR_N_BAGS  month  tot_kgs  Clus_km
# grade_id
# 1             71.0         0.0      3    230.0        1
# 1             63.0         0.0      3    196.0        1
# 1             74.0         0.0      3    560.0        2
# 1             84.0         0.0      3    420.0        1
# 1             63.0         0.0      3   1280.0        0

# %%
df_cat_2018 = pd.merge(left=df_cat_2018,right=df_grade_2018, left_on='GRD_CD', right_on='GRD_CD')
df_cat_2017 = pd.merge(left=df_cat_2017,right=df_grade_2017, left_on='GRD_CD', right_on='GRD_CD')
df_cat_2016 = pd.merge(left=df_cat_2016,right=df_grade_2016, left_on='GRD_CD', right_on='GRD_CD')

# %%
df_cat_2018.drop(['year_x'], axis=1, inplace = True)
df_cat_2017.drop(['year_x'], axis=1, inplace = True)
df_cat_2016.drop(['year_x'], axis=1, inplace = True)

# %%
df_cat_2018.values[:,3:]
# Out:
# array([[230.,   1.],
#        [196.,   1.],
#        [560.,   2.],
#        ...,
#        [140.,   1.],
#        [ 60.,   1.],
#        [192.,   1.]])

# %%
from sklearn.preprocessing import StandardScaler
X = df_cat_2018.values[:,3:]
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet
# Out:
# array([[-1.48819956, -0.21031719],
#        [-1.58312959, -0.21031719],
#        [-0.56681984,  0.99783567],
#        ...,
#        [-1.73948493, -0.21031719],
#        [-1.96284971, -0.21031719],
#        [-1.59429783, -0.21031719]])

# %%
clusterNum = 3
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
# Out:
# [1 1 1 ... 1 1 1]

# %%
df_cat_2018["Clus_km"] = labels
df_cat_2018.head(5)
# Out:
#           PUR_P_KG  PUR_N_BAGS  year_x  month  tot_kgs  Clus_km
# grade_id
# 1             71.0         0.0    2018      3    230.0        1
# 1             63.0         0.0    2018      3    196.0        1
# 1             74.0         0.0    2018      3    560.0        2
# 1             84.0         0.0    2018      3    420.0        1
# 1             63.0         0.0    2018      3   1280.0        0

# %%
df_cat_2018.groupby('Clus_km').mean()
# Out:
#            PUR_P_KG  PUR_N_BAGS     month      tot_kgs
# Clus_km
# 0        105.027283    3.138082  7.573346  1204.508566
# 1        115.939957    0.654923  6.838956   358.907649
# 2        106.955114    2.188257  7.345657   752.910406

# %%
X
# Out:
# array([[230.,   1.],
#        [196.,   1.],
#        [560.,   2.],
#        ...,
#        [140.,   1.],
#        [ 60.,   1.],
#        [192.,   1.]])

# %%
area = np.pi * ( X[:, 1])**2  
plt.scatter(X[:, 1], X[:, 0], s=area, c=labels.astype(np.float), alpha=0.5)
plt.xlabel('Grade', fontsize=18)
plt.ylabel('Kgs Sold', fontsize=16)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
# plt.ylabel('Month', fontsize=18)
# plt.xlabel('Grade', fontsize=16)
# plt.zlabel('Sold Kgs', fontsize=16)
ax.set_xlabel('Grade')
ax.set_ylabel('Month')
ax.set_zlabel('Sold Kgs')

ax.scatter(X[:, 1], X[:, 2], X[:, 0], c= labels.astype(np.float))
